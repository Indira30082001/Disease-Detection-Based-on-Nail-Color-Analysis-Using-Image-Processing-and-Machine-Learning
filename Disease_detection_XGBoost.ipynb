# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, log_loss
import numpy as np

# Define paths
train_path = 'C:/Users/mamid/OneDrive/Desktop/gradio_example/Disease-Detection-v1/archive/data/train'
validation_path = 'C:/Users/mamid/OneDrive/Desktop/gradio_example/Disease-Detection-v1/archive/data/validation'

# %%
def create_image_dataset(directory, img_size=(128, 128), batch_size=32):
    """Create a TensorFlow dataset from a directory of images."""
    datagen = ImageDataGenerator(rescale=1.0/255) 
    
    dataset = datagen.flow_from_directory(
        directory,
        target_size=img_size,
        batch_size=batch_size,
        class_mode='categorical',  
        shuffle=True
    )
    
    return dataset

# Create datasets
train_dataset = create_image_dataset(train_path)
val_dataset = create_image_dataset(validation_path)
# Out:
# Found 3735 images belonging to 6 classes.
# Found 85 images belonging to 6 classes.

# %%
# Create a CNN feature extractor
def create_feature_extractor(input_shape=(128, 128, 3)):
    model = Sequential([
        Conv2D(32, (3, 3), activation='relu', input_shape=input_shape),
        MaxPooling2D((2, 2)),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(256, activation='relu'),
        Dropout(0.5)
    ])
    return model

feature_extractor = create_feature_extractor()

# %%
#Extract features from images
def extract_features(dataset, feature_extractor):
    features = []
    labels = []
    
    # Reset generator to ensure we start from the beginning
    dataset.reset()
    
    # Calculate number of batches
    num_batches = len(dataset)
    
    for _ in range(num_batches):
        x, y = dataset.__next__()  
        features_batch = feature_extractor.predict(x)
        features.append(features_batch)
        labels.append(y)
        
    return np.vstack(features), np.vstack(labels)

# Extract features for training and validation
X_train, y_train = extract_features(train_dataset, feature_extractor)
X_val, y_val = extract_features(val_dataset, feature_extractor)

# Convert one-hot encoded labels back to class indices for XGBoost
y_train_labels = np.argmax(y_train, axis=1)
y_val_labels = np.argmax(y_val, axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step

# %%
#Train XGBoost model
xgb_model = XGBClassifier(
    n_estimators=100,
    max_depth=6,
    learning_rate=0.1,
    objective='multi:softprob',
    num_class=len(train_dataset.class_indices),
    n_jobs=-1
)

# %%
import numpy as np
import matplotlib.pyplot as plt
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, log_loss

# After creating your datasets and feature extractor, add this:
num_classes = len(train_dataset.class_indices)  # Get number of classes from the dataset


# Initialize history dictionary
history = {
    'train_loss': [],
    'val_loss': [],
    'train_acc': [],
    'val_acc': []
}

# Training parameters
epochs = 10
early_stopping_rounds = 5
best_loss = float('inf')
epochs_without_improvement = 0

for epoch in range(epochs):
    print(f"\nEpoch {epoch + 1}/{epochs}")
    
    # Fit the model
    xgb_model.fit(
        X_train, y_train_labels,
        eval_set=[(X_val, y_val_labels)],
        verbose=True,
        xgb_model=None if epoch == 0 else xgb_model
    )
    
    # Calculate metrics
    train_probs = xgb_model.predict_proba(X_train)
    val_probs = xgb_model.predict_proba(X_val)
    
    train_loss = log_loss(y_train_labels, train_probs)
    val_loss = log_loss(y_val_labels, val_probs)
    
    train_pred = np.argmax(train_probs, axis=1)
    val_pred = np.argmax(val_probs, axis=1)
    
    train_acc = accuracy_score(y_train_labels, train_pred)
    val_acc = accuracy_score(y_val_labels, val_pred)
    
    # Store metrics
    history['train_loss'].append(train_loss)
    history['val_loss'].append(val_loss)
    history['train_acc'].append(train_acc)
    history['val_acc'].append(val_acc)
    
    print(f"Train Loss: {train_loss:.4f} - Train Acc: {train_acc:.4f}")
    print(f"Val Loss: {val_loss:.4f} - Val Acc: {val_acc:.4f}")
    
    # Early stopping check
    if val_loss < best_loss:
        best_loss = val_loss
        epochs_without_improvement = 0
    else:
        epochs_without_improvement += 1
        if epochs_without_improvement >= early_stopping_rounds:
            print(f"\nEarly stopping at epoch {epoch + 1}")
            break

# Plotting the history
plt.figure(figsize=(12, 5))

# Loss plot
plt.subplot(1, 2, 1)
plt.plot(history['train_loss'], 'b-', label='Train Loss')
plt.plot(history['val_loss'], 'r-', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)

# Accuracy plot
plt.subplot(1, 2, 2)
plt.plot(history['train_acc'], 'b-', label='Train Accuracy')
plt.plot(history['val_acc'], 'r-', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# Final evaluation
final_val_pred = xgb_model.predict(X_val)
final_val_acc = accuracy_score(y_val_labels, final_val_pred)
final_val_probs = xgb_model.predict_proba(X_val)
final_val_loss = log_loss(y_val_labels, final_val_probs)

print("\nFinal Evaluation:")
print(f"Number of classes: {num_classes}")
print(f"Validation Loss: {final_val_loss:.4f}")
print(f"Validation Accuracy: {final_val_acc:.4f}")
# Out:
# Epoch 1/10
# [0]	validation_0-mlogloss:1.72714
# [1]	validation_0-mlogloss:1.68746
# [2]	validation_0-mlogloss:1.65193
# [3]	validation_0-mlogloss:1.61705
# [4]	validation_0-mlogloss:1.58659
# [5]	validation_0-mlogloss:1.56300
# [6]	validation_0-mlogloss:1.55072
# [7]	validation_0-mlogloss:1.53045
# [8]	validation_0-mlogloss:1.51586
# [9]	validation_0-mlogloss:1.50346
# [10]	validation_0-mlogloss:1.49217
# [11]	validation_0-mlogloss:1.47614
# [12]	validation_0-mlogloss:1.46210
# [13]	validation_0-mlogloss:1.44755
# [14]	validation_0-mlogloss:1.44019
# [15]	validation_0-mlogloss:1.42596
# [16]	validation_0-mlogloss:1.42033
# [17]	validation_0-mlogloss:1.40364
# [18]	validation_0-mlogloss:1.39325
# [19]	validation_0-mlogloss:1.39193
# [20]	validation_0-mlogloss:1.38484
# [21]	validation_0-mlogloss:1.37524
# [22]	validation_0-mlogloss:1.36749
# [23]	validation_0-mlogloss:1.35440
# [24]	validation_0-mlogloss:1.35123
# [25]	validation_0-mlogloss:1.34589
# [26]	validation_0-mlogloss:1.33806
# [27]	validation_0-mlogloss:1.33220
# [28]	validation_0-mlogloss:1.32606
# [29]	validation_0-mlogloss:1.32273
# [30]	validation_0-mlogloss:1.31668
# [31]	validation_0-mlogloss:1.31390
# [32]	validation_0-mlogloss:1.30993
# [33]	validation_0-mlogloss:1.30417
# [34]	validation_0-mlogloss:1.30003
# [35]	validation_0-mlogloss:1.29481
# [36]	validation_0-mlogloss:1.29061
# [37]	validation_0-mlogloss:1.29299
# [38]	validation_0-mlogloss:1.28908
# [39]	validation_0-mlogloss:1.28424
# [40]	validation_0-mlogloss:1.27949
# [41]	validation_0-mlogloss:1.27635
# [42]	validation_0-mlogloss:1.27412
# [43]	validation_0-mlogloss:1.27428
# [44]	validation_0-mlogloss:1.27036
# [45]	validation_0-mlogloss:1.26926
# [46]	validation_0-mlogloss:1.26733
# [47]	validation_0-mlogloss:1.26408
# [48]	validation_0-mlogloss:1.26408
# [49]	validation_0-mlogloss:1.25951
# [50]	validation_0-mlogloss:1.25726
# [51]	validation_0-mlogloss:1.25734
# [52]	validation_0-mlogloss:1.25634
# [53]	validation_0-mlogloss:1.25805
# [54]	validation_0-mlogloss:1.25675
# [55]	validation_0-mlogloss:1.25480
# [56]	validation_0-mlogloss:1.25392
# [57]	validation_0-mlogloss:1.25151
# [58]	validation_0-mlogloss:1.25158
# [59]	validation_0-mlogloss:1.24832
# [60]	validation_0-mlogloss:1.24794
# [61]	validation_0-mlogloss:1.24876
# [62]	validation_0-mlogloss:1.24816
# [63]	validation_0-mlogloss:1.24797
# [64]	validation_0-mlogloss:1.24615
# [65]	validation_0-mlogloss:1.24291
# [66]	validation_0-mlogloss:1.24283
# [67]	validation_0-mlogloss:1.24608
# [68]	validation_0-mlogloss:1.24648
# [69]	validation_0-mlogloss:1.24477
# [70]	validation_0-mlogloss:1.24617
# [71]	validation_0-mlogloss:1.24606
# [72]	validation_0-mlogloss:1.24036
# [73]	validation_0-mlogloss:1.24095
# [74]	validation_0-mlogloss:1.23632
# [75]	validation_0-mlogloss:1.23552
# [76]	validation_0-mlogloss:1.23575
# [77]	validation_0-mlogloss:1.23723
# [78]	validation_0-mlogloss:1.23736
# [79]	validation_0-mlogloss:1.23350
# [80]	validation_0-mlogloss:1.23143
# [81]	validation_0-mlogloss:1.23110
# [82]	validation_0-mlogloss:1.23090
# [83]	validation_0-mlogloss:1.22934
# [84]	validation_0-mlogloss:1.22986
# [85]	validation_0-mlogloss:1.22890
# [86]	validation_0-mlogloss:1.22667
# [87]	validation_0-mlogloss:1.22554
# [88]	validation_0-mlogloss:1.22442
# [89]	validation_0-mlogloss:1.22353
# [90]	validation_0-mlogloss:1.22234
# [91]	validation_0-mlogloss:1.22429
# [92]	validation_0-mlogloss:1.22278
# [93]	validation_0-mlogloss:1.22563
# [94]	validation_0-mlogloss:1.22736
# [95]	validation_0-mlogloss:1.22908
# [96]	validation_0-mlogloss:1.23008
# [97]	validation_0-mlogloss:1.22773
# [98]	validation_0-mlogloss:1.22710
# [99]	validation_0-mlogloss:1.22689
# Train Loss: 0.2349 - Train Acc: 0.9997
# Val Loss: 1.2269 - Val Acc: 0.5059
#
# Epoch 2/10
# [0]	validation_0-mlogloss:1.22867
# [1]	validation_0-mlogloss:1.22907
# [2]	validation_0-mlogloss:1.22908
# [3]	validation_0-mlogloss:1.22694
# [4]	validation_0-mlogloss:1.22518
# [5]	validation_0-mlogloss:1.22536
# [6]	validation_0-mlogloss:1.22722
# [7]	validation_0-mlogloss:1.22846
# [8]	validation_0-mlogloss:1.22553
# [9]	validation_0-mlogloss:1.22436
# [10]	validation_0-mlogloss:1.22565
# [11]	validation_0-mlogloss:1.22485
# [12]	validation_0-mlogloss:1.22285
# [13]	validation_0-mlogloss:1.22353
# [14]	validation_0-mlogloss:1.22142
# [15]	validation_0-mlogloss:1.22164
# [16]	validation_0-mlogloss:1.21888
# [17]	validation_0-mlogloss:1.21586
# [18]	validation_0-mlogloss:1.21485
# [19]	validation_0-mlogloss:1.21429
# [20]	validation_0-mlogloss:1.21319
# [21]	validation_0-mlogloss:1.21110
# [22]	validation_0-mlogloss:1.21006
# [23]	validation_0-mlogloss:1.21302
# [24]	validation_0-mlogloss:1.21165
# [25]	validation_0-mlogloss:1.21286
# [26]	validation_0-mlogloss:1.21207
# [27]	validation_0-mlogloss:1.21269
# [28]	validation_0-mlogloss:1.21324
# [29]	validation_0-mlogloss:1.21315
# [30]	validation_0-mlogloss:1.21577
# [31]	validation_0-mlogloss:1.21950
# [32]	validation_0-mlogloss:1.21840
# [33]	validation_0-mlogloss:1.21852
# [34]	validation_0-mlogloss:1.21700
# [35]	validation_0-mlogloss:1.22030
# [36]	validation_0-mlogloss:1.21949
# [37]	validation_0-mlogloss:1.21879
# [38]	validation_0-mlogloss:1.21984
# [39]	validation_0-mlogloss:1.21891
# [40]	validation_0-mlogloss:1.21869
# [41]	validation_0-mlogloss:1.21940
# [42]	validation_0-mlogloss:1.21642
# [43]	validation_0-mlogloss:1.21728
# [44]	validation_0-mlogloss:1.21754
# [45]	validation_0-mlogloss:1.21772
# [46]	validation_0-mlogloss:1.21861
# [47]	validation_0-mlogloss:1.21934
# [48]	validation_0-mlogloss:1.22263
# [49]	validation_0-mlogloss:1.22284
# [50]	validation_0-mlogloss:1.22330
# [51]	validation_0-mlogloss:1.22297
# [52]	validation_0-mlogloss:1.22164
# [53]	validation_0-mlogloss:1.22422
# [54]	validation_0-mlogloss:1.22481
# [55]	validation_0-mlogloss:1.22533
# [56]	validation_0-mlogloss:1.22377
# [57]	validation_0-mlogloss:1.22348
# [58]	validation_0-mlogloss:1.22217
# [59]	validation_0-mlogloss:1.22258
# [60]	validation_0-mlogloss:1.22403
# [61]	validation_0-mlogloss:1.22274
# [62]	validation_0-mlogloss:1.22135
# [63]	validation_0-mlogloss:1.22095
# [64]	validation_0-mlogloss:1.22127
# [65]	validation_0-mlogloss:1.22117
# [66]	validation_0-mlogloss:1.21949
# [67]	validation_0-mlogloss:1.22136
# [68]	validation_0-mlogloss:1.22132
# [69]	validation_0-mlogloss:1.22066
# [70]	validation_0-mlogloss:1.21942
# [71]	validation_0-mlogloss:1.21687
# [72]	validation_0-mlogloss:1.21601
# [73]	validation_0-mlogloss:1.21566
# [74]	validation_0-mlogloss:1.21511
# [75]	validation_0-mlogloss:1.21725
# [76]	validation_0-mlogloss:1.21700
# [77]	validation_0-mlogloss:1.21693
# [78]	validation_0-mlogloss:1.21696
# [79]	validation_0-mlogloss:1.21830
# [80]	validation_0-mlogloss:1.21766
# [81]	validation_0-mlogloss:1.21796
# [82]	validation_0-mlogloss:1.21640
# [83]	validation_0-mlogloss:1.21498
# [84]	validation_0-mlogloss:1.21478
# [85]	validation_0-mlogloss:1.21400
# [86]	validation_0-mlogloss:1.21248
# [87]	validation_0-mlogloss:1.21324
# [88]	validation_0-mlogloss:1.21246
# [89]	validation_0-mlogloss:1.21038
# [90]	validation_0-mlogloss:1.21211
# [91]	validation_0-mlogloss:1.21125
# [92]	validation_0-mlogloss:1.21017
# [93]	validation_0-mlogloss:1.20766
# [94]	validation_0-mlogloss:1.20709
# [95]	validation_0-mlogloss:1.20745
# [96]	validation_0-mlogloss:1.20533
# [97]	validation_0-mlogloss:1.20458
# [98]	validation_0-mlogloss:1.20294
# [99]	validation_0-mlogloss:1.20584
# Train Loss: 0.0594 - Train Acc: 1.0000
# Val Loss: 1.2058 - Val Acc: 0.5529
#
# Epoch 3/10
# [0]	validation_0-mlogloss:1.20673
# [1]	validation_0-mlogloss:1.20426
# [2]	validation_0-mlogloss:1.20490
# [3]	validation_0-mlogloss:1.20553
# [4]	validation_0-mlogloss:1.20372
# [5]	validation_0-mlogloss:1.20029
# [6]	validation_0-mlogloss:1.19924
# [7]	validation_0-mlogloss:1.20086
# [8]	validation_0-mlogloss:1.20123
# [9]	validation_0-mlogloss:1.20075
# [10]	validation_0-mlogloss:1.20110
# [11]	validation_0-mlogloss:1.20167
# [12]	validation_0-mlogloss:1.20314
# [13]	validation_0-mlogloss:1.20396
# [14]	validation_0-mlogloss:1.20473
# [15]	validation_0-mlogloss:1.20438
# [16]	validation_0-mlogloss:1.20684
# [17]	validation_0-mlogloss:1.20622
# [18]	validation_0-mlogloss:1.20651
# [19]	validation_0-mlogloss:1.20601
# [20]	validation_0-mlogloss:1.20816
# [21]	validation_0-mlogloss:1.20618
# [22]	validation_0-mlogloss:1.20538
# [23]	validation_0-mlogloss:1.20573
# [24]	validation_0-mlogloss:1.20813
# [25]	validation_0-mlogloss:1.20787
# [26]	validation_0-mlogloss:1.20805
# [27]	validation_0-mlogloss:1.20831
# [28]	validation_0-mlogloss:1.20922
# [29]	validation_0-mlogloss:1.20921
# [30]	validation_0-mlogloss:1.20743
# [31]	validation_0-mlogloss:1.20693
# [32]	validation_0-mlogloss:1.20812
# [33]	validation_0-mlogloss:1.20761
# [34]	validation_0-mlogloss:1.20741
# [35]	validation_0-mlogloss:1.20750
# [36]	validation_0-mlogloss:1.20568
# [37]	validation_0-mlogloss:1.20524
# [38]	validation_0-mlogloss:1.20638
# [39]	validation_0-mlogloss:1.20643
# [40]	validation_0-mlogloss:1.20798
# [41]	validation_0-mlogloss:1.20901
# [42]	validation_0-mlogloss:1.21077
# [43]	validation_0-mlogloss:1.21048
# [44]	validation_0-mlogloss:1.21142
# [45]	validation_0-mlogloss:1.21001
# [46]	validation_0-mlogloss:1.21020
# [47]	validation_0-mlogloss:1.20887
# [48]	validation_0-mlogloss:1.20950
# [49]	validation_0-mlogloss:1.21011
# [50]	validation_0-mlogloss:1.21035
# [51]	validation_0-mlogloss:1.21163
# [52]	validation_0-mlogloss:1.21167
# [53]	validation_0-mlogloss:1.21062
# [54]	validation_0-mlogloss:1.20872
# [55]	validation_0-mlogloss:1.21093
# [56]	validation_0-mlogloss:1.21175
# [57]	validation_0-mlogloss:1.21246
# [58]	validation_0-mlogloss:1.21252
# [59]	validation_0-mlogloss:1.21129
# [60]	validation_0-mlogloss:1.21347
# [61]	validation_0-mlogloss:1.21305
# [62]	validation_0-mlogloss:1.21410
# [63]	validation_0-mlogloss:1.21493
# [64]	validation_0-mlogloss:1.21525
# [65]	validation_0-mlogloss:1.21595
# [66]	validation_0-mlogloss:1.21661
# [67]	validation_0-mlogloss:1.21661
# [68]	validation_0-mlogloss:1.21534
# [69]	validation_0-mlogloss:1.21549
# [70]	validation_0-mlogloss:1.21688
# [71]	validation_0-mlogloss:1.21620
# [72]	validation_0-mlogloss:1.21643
# [73]	validation_0-mlogloss:1.21520
# [74]	validation_0-mlogloss:1.21511
# [75]	validation_0-mlogloss:1.21501
# [76]	validation_0-mlogloss:1.21509
# [77]	validation_0-mlogloss:1.21371
# [78]	validation_0-mlogloss:1.21404
# [79]	validation_0-mlogloss:1.21641
# [80]	validation_0-mlogloss:1.21581
# [81]	validation_0-mlogloss:1.21537
# [82]	validation_0-mlogloss:1.21625
# [83]	validation_0-mlogloss:1.21620
# [84]	validation_0-mlogloss:1.21796
# [85]	validation_0-mlogloss:1.21788
# [86]	validation_0-mlogloss:1.21858
# [87]	validation_0-mlogloss:1.21938
# [88]	validation_0-mlogloss:1.21981
# [89]	validation_0-mlogloss:1.22004
# [90]	validation_0-mlogloss:1.21889
# [91]	validation_0-mlogloss:1.21911
# [92]	validation_0-mlogloss:1.21947
# [93]	validation_0-mlogloss:1.21810
# [94]	validation_0-mlogloss:1.21847
# [95]	validation_0-mlogloss:1.21741
# [96]	validation_0-mlogloss:1.21889
# [97]	validation_0-mlogloss:1.21967
# [98]	validation_0-mlogloss:1.21804
# [99]	validation_0-mlogloss:1.21925
# Train Loss: 0.0238 - Train Acc: 1.0000
# Val Loss: 1.2192 - Val Acc: 0.5647
#
# Epoch 4/10
# [0]	validation_0-mlogloss:1.21945
# [1]	validation_0-mlogloss:1.22004
# [2]	validation_0-mlogloss:1.21962
# [3]	validation_0-mlogloss:1.22025
# [4]	validation_0-mlogloss:1.22024
# [5]	validation_0-mlogloss:1.21972
# [6]	validation_0-mlogloss:1.22123
# [7]	validation_0-mlogloss:1.21990
# [8]	validation_0-mlogloss:1.21949
# [9]	validation_0-mlogloss:1.22046
# [10]	validation_0-mlogloss:1.22105
# [11]	validation_0-mlogloss:1.21925
# [12]	validation_0-mlogloss:1.21951
# [13]	validation_0-mlogloss:1.21981
# [14]	validation_0-mlogloss:1.22051
# [15]	validation_0-mlogloss:1.21996
# [16]	validation_0-mlogloss:1.22042
# [17]	validation_0-mlogloss:1.21939
# [18]	validation_0-mlogloss:1.21932
# [19]	validation_0-mlogloss:1.21832
# [20]	validation_0-mlogloss:1.21722
# [21]	validation_0-mlogloss:1.21656
# [22]	validation_0-mlogloss:1.21647
# [23]	validation_0-mlogloss:1.21616
# [24]	validation_0-mlogloss:1.21596
# [25]	validation_0-mlogloss:1.21647
# [26]	validation_0-mlogloss:1.21693
# [27]	validation_0-mlogloss:1.21659
# [28]	validation_0-mlogloss:1.21604
# [29]	validation_0-mlogloss:1.21500
# [30]	validation_0-mlogloss:1.21492
# [31]	validation_0-mlogloss:1.21402
# [32]	validation_0-mlogloss:1.21423
# [33]	validation_0-mlogloss:1.21457
# [34]	validation_0-mlogloss:1.21535
# [35]	validation_0-mlogloss:1.21513
# [36]	validation_0-mlogloss:1.21495
# [37]	validation_0-mlogloss:1.21536
# [38]	validation_0-mlogloss:1.21694
# [39]	validation_0-mlogloss:1.21724
# [40]	validation_0-mlogloss:1.21723
# [41]	validation_0-mlogloss:1.21769
# [42]	validation_0-mlogloss:1.21884
# [43]	validation_0-mlogloss:1.21906
# [44]	validation_0-mlogloss:1.21904
# [45]	validation_0-mlogloss:1.21967
# [46]	validation_0-mlogloss:1.21928
# [47]	validation_0-mlogloss:1.21972
# [48]	validation_0-mlogloss:1.21930
# [49]	validation_0-mlogloss:1.21880
# [50]	validation_0-mlogloss:1.21903
# [51]	validation_0-mlogloss:1.21978
# [52]	validation_0-mlogloss:1.22014
# [53]	validation_0-mlogloss:1.22068
# [54]	validation_0-mlogloss:1.22064
# [55]	validation_0-mlogloss:1.22040
# [56]	validation_0-mlogloss:1.22084
# [57]	validation_0-mlogloss:1.22123
# [58]	validation_0-mlogloss:1.22300
# [59]	validation_0-mlogloss:1.22179
# [60]	validation_0-mlogloss:1.22244
# [61]	validation_0-mlogloss:1.22415
# [62]	validation_0-mlogloss:1.22364
# [63]	validation_0-mlogloss:1.22328
# [64]	validation_0-mlogloss:1.22410
# [65]	validation_0-mlogloss:1.22550
# [66]	validation_0-mlogloss:1.22587
# [67]	validation_0-mlogloss:1.22559
# [68]	validation_0-mlogloss:1.22585
# [69]	validation_0-mlogloss:1.22541
# [70]	validation_0-mlogloss:1.22429
# [71]	validation_0-mlogloss:1.22504
# [72]	validation_0-mlogloss:1.22421
# [73]	validation_0-mlogloss:1.22333
# [74]	validation_0-mlogloss:1.22248
# [75]	validation_0-mlogloss:1.22193
# [76]	validation_0-mlogloss:1.22134
# [77]	validation_0-mlogloss:1.22277
# [78]	validation_0-mlogloss:1.22275
# [79]	validation_0-mlogloss:1.22328
# [80]	validation_0-mlogloss:1.22357
# [81]	validation_0-mlogloss:1.22331
# [82]	validation_0-mlogloss:1.22414
# [83]	validation_0-mlogloss:1.22528
# [84]	validation_0-mlogloss:1.22489
# [85]	validation_0-mlogloss:1.22547
# [86]	validation_0-mlogloss:1.22655
# [87]	validation_0-mlogloss:1.22813
# [88]	validation_0-mlogloss:1.22709
# [89]	validation_0-mlogloss:1.22777
# [90]	validation_0-mlogloss:1.22782
# [91]	validation_0-mlogloss:1.22821
# [92]	validation_0-mlogloss:1.22832
# [93]	validation_0-mlogloss:1.22790
# [94]	validation_0-mlogloss:1.22730
# [95]	validation_0-mlogloss:1.22745
# [96]	validation_0-mlogloss:1.22878
# [97]	validation_0-mlogloss:1.22970
# [98]	validation_0-mlogloss:1.22962
# [99]	validation_0-mlogloss:1.22989
# Train Loss: 0.0128 - Train Acc: 1.0000
# Val Loss: 1.2299 - Val Acc: 0.5647
#
# Epoch 5/10
# [0]	validation_0-mlogloss:1.23023
# [1]	validation_0-mlogloss:1.23090
# [2]	validation_0-mlogloss:1.23109
# [3]	validation_0-mlogloss:1.23023
# [4]	validation_0-mlogloss:1.23183
# [5]	validation_0-mlogloss:1.23386
# [6]	validation_0-mlogloss:1.23410
# [7]	validation_0-mlogloss:1.23456
# [8]	validation_0-mlogloss:1.23348
# [9]	validation_0-mlogloss:1.23364
# [10]	validation_0-mlogloss:1.23246
# [11]	validation_0-mlogloss:1.23274
# [12]	validation_0-mlogloss:1.23246
# [13]	validation_0-mlogloss:1.23206
# [14]	validation_0-mlogloss:1.23044
# [15]	validation_0-mlogloss:1.23155
# [16]	validation_0-mlogloss:1.23231
# [17]	validation_0-mlogloss:1.23232
# [18]	validation_0-mlogloss:1.23258
# [19]	validation_0-mlogloss:1.23185
# [20]	validation_0-mlogloss:1.23181
# [21]	validation_0-mlogloss:1.23092
# [22]	validation_0-mlogloss:1.23148
# [23]	validation_0-mlogloss:1.23208
# [24]	validation_0-mlogloss:1.23305
# [25]	validation_0-mlogloss:1.23343
# [26]	validation_0-mlogloss:1.23412
# [27]	validation_0-mlogloss:1.23399
# [28]	validation_0-mlogloss:1.23436
# [29]	validation_0-mlogloss:1.23496
# [30]	validation_0-mlogloss:1.23347
# [31]	validation_0-mlogloss:1.23269
# [32]	validation_0-mlogloss:1.23327
# [33]	validation_0-mlogloss:1.23379
# [34]	validation_0-mlogloss:1.23470
# [35]	validation_0-mlogloss:1.23478
# [36]	validation_0-mlogloss:1.23507
# [37]	validation_0-mlogloss:1.23581
# [38]	validation_0-mlogloss:1.23498
# [39]	validation_0-mlogloss:1.23527
# [40]	validation_0-mlogloss:1.23546
# [41]	validation_0-mlogloss:1.23521
# [42]	validation_0-mlogloss:1.23503
# [43]	validation_0-mlogloss:1.23452
# [44]	validation_0-mlogloss:1.23523
# [45]	validation_0-mlogloss:1.23486
# [46]	validation_0-mlogloss:1.23494
# [47]	validation_0-mlogloss:1.23491
# [48]	validation_0-mlogloss:1.23569
# [49]	validation_0-mlogloss:1.23485
# [50]	validation_0-mlogloss:1.23534
# [51]	validation_0-mlogloss:1.23462
# [52]	validation_0-mlogloss:1.23544
# [53]	validation_0-mlogloss:1.23553
# [54]	validation_0-mlogloss:1.23478
# [55]	validation_0-mlogloss:1.23399
# [56]	validation_0-mlogloss:1.23275
# [57]	validation_0-mlogloss:1.23305
# [58]	validation_0-mlogloss:1.23299
# [59]	validation_0-mlogloss:1.23372
# [60]	validation_0-mlogloss:1.23286
# [61]	validation_0-mlogloss:1.23362
# [62]	validation_0-mlogloss:1.23415
# [63]	validation_0-mlogloss:1.23441
# [64]	validation_0-mlogloss:1.23423
# [65]	validation_0-mlogloss:1.23333
# [66]	validation_0-mlogloss:1.23309
# [67]	validation_0-mlogloss:1.23272
# [68]	validation_0-mlogloss:1.23383
# [69]	validation_0-mlogloss:1.23493
# [70]	validation_0-mlogloss:1.23511
# [71]	validation_0-mlogloss:1.23508
# [72]	validation_0-mlogloss:1.23430
# [73]	validation_0-mlogloss:1.23365
# [74]	validation_0-mlogloss:1.23346
# [75]	validation_0-mlogloss:1.23404
# [76]	validation_0-mlogloss:1.23454
# [77]	validation_0-mlogloss:1.23520
# [78]	validation_0-mlogloss:1.23476
# [79]	validation_0-mlogloss:1.23589
# [80]	validation_0-mlogloss:1.23614
# [81]	validation_0-mlogloss:1.23570
# [82]	validation_0-mlogloss:1.23576
# [83]	validation_0-mlogloss:1.23538
# [84]	validation_0-mlogloss:1.23492
# [85]	validation_0-mlogloss:1.23392
# [86]	validation_0-mlogloss:1.23388
# [87]	validation_0-mlogloss:1.23444
# [88]	validation_0-mlogloss:1.23462
# [89]	validation_0-mlogloss:1.23455
# [90]	validation_0-mlogloss:1.23455
# [91]	validation_0-mlogloss:1.23382
# [92]	validation_0-mlogloss:1.23380
# [93]	validation_0-mlogloss:1.23421
# [94]	validation_0-mlogloss:1.23364
# [95]	validation_0-mlogloss:1.23342
# [96]	validation_0-mlogloss:1.23358
# [97]	validation_0-mlogloss:1.23351
# [98]	validation_0-mlogloss:1.23323
# [99]	validation_0-mlogloss:1.23280
# Train Loss: 0.0084 - Train Acc: 1.0000
# Val Loss: 1.2328 - Val Acc: 0.5882
#
# Epoch 6/10
# [0]	validation_0-mlogloss:1.23227
# [1]	validation_0-mlogloss:1.23248
# [2]	validation_0-mlogloss:1.23294
# [3]	validation_0-mlogloss:1.23340
# [4]	validation_0-mlogloss:1.23288
# [5]	validation_0-mlogloss:1.23273
# [6]	validation_0-mlogloss:1.23351
# [7]	validation_0-mlogloss:1.23393
# [8]	validation_0-mlogloss:1.23440
# [9]	validation_0-mlogloss:1.23415
# [10]	validation_0-mlogloss:1.23332
# [11]	validation_0-mlogloss:1.23359
# [12]	validation_0-mlogloss:1.23428
# [13]	validation_0-mlogloss:1.23441
# [14]	validation_0-mlogloss:1.23496
# [15]	validation_0-mlogloss:1.23497
# [16]	validation_0-mlogloss:1.23611
# [17]	validation_0-mlogloss:1.23603
# [18]	validation_0-mlogloss:1.23637
# [19]	validation_0-mlogloss:1.23725
# [20]	validation_0-mlogloss:1.23729
# [21]	validation_0-mlogloss:1.23838
# [22]	validation_0-mlogloss:1.23838
# [23]	validation_0-mlogloss:1.23830
# [24]	validation_0-mlogloss:1.23826
# [25]	validation_0-mlogloss:1.23910
# [26]	validation_0-mlogloss:1.23833
# [27]	validation_0-mlogloss:1.23859
# [28]	validation_0-mlogloss:1.23971
# [29]	validation_0-mlogloss:1.23978
# [30]	validation_0-mlogloss:1.23972
# [31]	validation_0-mlogloss:1.23922
# [32]	validation_0-mlogloss:1.24018
# [33]	validation_0-mlogloss:1.23975
# [34]	validation_0-mlogloss:1.24023
# [35]	validation_0-mlogloss:1.24136
# [36]	validation_0-mlogloss:1.24042
# [37]	validation_0-mlogloss:1.23999
# [38]	validation_0-mlogloss:1.24063
# [39]	validation_0-mlogloss:1.24025
# [40]	validation_0-mlogloss:1.24102
# [41]	validation_0-mlogloss:1.24181
# [42]	validation_0-mlogloss:1.24224
# [43]	validation_0-mlogloss:1.24259
# [44]	validation_0-mlogloss:1.24217
# [45]	validation_0-mlogloss:1.24211
# [46]	validation_0-mlogloss:1.24273
# [47]	validation_0-mlogloss:1.24183
# [48]	validation_0-mlogloss:1.24177
# [49]	validation_0-mlogloss:1.24179
# [50]	validation_0-mlogloss:1.24243
# [51]	validation_0-mlogloss:1.24264
# [52]	validation_0-mlogloss:1.24228
# [53]	validation_0-mlogloss:1.24276
# [54]	validation_0-mlogloss:1.24225
# [55]	validation_0-mlogloss:1.24227
# [56]	validation_0-mlogloss:1.24264
# [57]	validation_0-mlogloss:1.24300
# [58]	validation_0-mlogloss:1.24378
# [59]	validation_0-mlogloss:1.24322
# [60]	validation_0-mlogloss:1.24263
# [61]	validation_0-mlogloss:1.24304
# [62]	validation_0-mlogloss:1.24309
# [63]	validation_0-mlogloss:1.24377
# [64]	validation_0-mlogloss:1.24300
# [65]	validation_0-mlogloss:1.24233
# [66]	validation_0-mlogloss:1.24245
# [67]	validation_0-mlogloss:1.24293
# [68]	validation_0-mlogloss:1.24357
# [69]	validation_0-mlogloss:1.24364
# [70]	validation_0-mlogloss:1.24511
# [71]	validation_0-mlogloss:1.24607
# [72]	validation_0-mlogloss:1.24629
# [73]	validation_0-mlogloss:1.24654
# [74]	validation_0-mlogloss:1.24639
# [75]	validation_0-mlogloss:1.24645
# [76]	validation_0-mlogloss:1.24702
# [77]	validation_0-mlogloss:1.24702
# [78]	validation_0-mlogloss:1.24690
# [79]	validation_0-mlogloss:1.24642
# [80]	validation_0-mlogloss:1.24515
# [81]	validation_0-mlogloss:1.24567
# [82]	validation_0-mlogloss:1.24619
# [83]	validation_0-mlogloss:1.24549
# [84]	validation_0-mlogloss:1.24519
# [85]	validation_0-mlogloss:1.24550
# [86]	validation_0-mlogloss:1.24613
# [87]	validation_0-mlogloss:1.24561
# [88]	validation_0-mlogloss:1.24538
# [89]	validation_0-mlogloss:1.24570
# [90]	validation_0-mlogloss:1.24511
# [91]	validation_0-mlogloss:1.24453
# [92]	validation_0-mlogloss:1.24541
# [93]	validation_0-mlogloss:1.24556
# [94]	validation_0-mlogloss:1.24616
# [95]	validation_0-mlogloss:1.24686
# [96]	validation_0-mlogloss:1.24738
# [97]	validation_0-mlogloss:1.24747
# [98]	validation_0-mlogloss:1.24763
# [99]	validation_0-mlogloss:1.24712
# Train Loss: 0.0063 - Train Acc: 1.0000
# Val Loss: 1.2471 - Val Acc: 0.5882
#
# Epoch 7/10
# [0]	validation_0-mlogloss:1.24795
# [1]	validation_0-mlogloss:1.24822
# [2]	validation_0-mlogloss:1.24803
# [3]	validation_0-mlogloss:1.24821
# [4]	validation_0-mlogloss:1.24791
# [5]	validation_0-mlogloss:1.24759
# [6]	validation_0-mlogloss:1.24750
# [7]	validation_0-mlogloss:1.24823
# [8]	validation_0-mlogloss:1.24929
# [9]	validation_0-mlogloss:1.24905
# [10]	validation_0-mlogloss:1.24942
# [11]	validation_0-mlogloss:1.25046
# [12]	validation_0-mlogloss:1.25042
# [13]	validation_0-mlogloss:1.25016
# [14]	validation_0-mlogloss:1.25028
# [15]	validation_0-mlogloss:1.24936
# [16]	validation_0-mlogloss:1.24906
# [17]	validation_0-mlogloss:1.24818
# [18]	validation_0-mlogloss:1.24810
# [19]	validation_0-mlogloss:1.24781
# [20]	validation_0-mlogloss:1.24869
# [21]	validation_0-mlogloss:1.24992
# [22]	validation_0-mlogloss:1.25072
# [23]	validation_0-mlogloss:1.25112
# [24]	validation_0-mlogloss:1.25188
# [25]	validation_0-mlogloss:1.25186
# [26]	validation_0-mlogloss:1.25232
# [27]	validation_0-mlogloss:1.25284
# [28]	validation_0-mlogloss:1.25260
# [29]	validation_0-mlogloss:1.25285
# [30]	validation_0-mlogloss:1.25349
# [31]	validation_0-mlogloss:1.25268
# [32]	validation_0-mlogloss:1.25342
# [33]	validation_0-mlogloss:1.25468
# [34]	validation_0-mlogloss:1.25450
# [35]	validation_0-mlogloss:1.25395
# [36]	validation_0-mlogloss:1.25378
# [37]	validation_0-mlogloss:1.25392
# [38]	validation_0-mlogloss:1.25486
# [39]	validation_0-mlogloss:1.25362
# [40]	validation_0-mlogloss:1.25394
# [41]	validation_0-mlogloss:1.25390
# [42]	validation_0-mlogloss:1.25415
# [43]	validation_0-mlogloss:1.25449
# [44]	validation_0-mlogloss:1.25389
# [45]	validation_0-mlogloss:1.25387
# [46]	validation_0-mlogloss:1.25502
# [47]	validation_0-mlogloss:1.25494
# [48]	validation_0-mlogloss:1.25539
# [49]	validation_0-mlogloss:1.25598
# [50]	validation_0-mlogloss:1.25582
# [51]	validation_0-mlogloss:1.25572
# [52]	validation_0-mlogloss:1.25619
# [53]	validation_0-mlogloss:1.25616
# [54]	validation_0-mlogloss:1.25544
# [55]	validation_0-mlogloss:1.25562
# [56]	validation_0-mlogloss:1.25594
# [57]	validation_0-mlogloss:1.25626
# [58]	validation_0-mlogloss:1.25710
# [59]	validation_0-mlogloss:1.25706
# [60]	validation_0-mlogloss:1.25719
# [61]	validation_0-mlogloss:1.25766
# [62]	validation_0-mlogloss:1.25786
# [63]	validation_0-mlogloss:1.25801
# [64]	validation_0-mlogloss:1.25741
# [65]	validation_0-mlogloss:1.25737
# [66]	validation_0-mlogloss:1.25763
# [67]	validation_0-mlogloss:1.25745
# [68]	validation_0-mlogloss:1.25799
# [69]	validation_0-mlogloss:1.25775
# [70]	validation_0-mlogloss:1.25787
# [71]	validation_0-mlogloss:1.25779
# [72]	validation_0-mlogloss:1.25751
# [73]	validation_0-mlogloss:1.25770
# [74]	validation_0-mlogloss:1.25809
# [75]	validation_0-mlogloss:1.25853
# [76]	validation_0-mlogloss:1.25818
# [77]	validation_0-mlogloss:1.25877
# [78]	validation_0-mlogloss:1.25891
# [79]	validation_0-mlogloss:1.25955
# [80]	validation_0-mlogloss:1.25966
# [81]	validation_0-mlogloss:1.26006
# [82]	validation_0-mlogloss:1.26002
# [83]	validation_0-mlogloss:1.26048
# [84]	validation_0-mlogloss:1.25990
# [85]	validation_0-mlogloss:1.26028
# [86]	validation_0-mlogloss:1.26022
# [87]	validation_0-mlogloss:1.25961
# [88]	validation_0-mlogloss:1.25978
# [89]	validation_0-mlogloss:1.25936
# [90]	validation_0-mlogloss:1.25884
# [91]	validation_0-mlogloss:1.25822
# [92]	validation_0-mlogloss:1.25797
# [93]	validation_0-mlogloss:1.25697
# [94]	validation_0-mlogloss:1.25692
# [95]	validation_0-mlogloss:1.25665
# [96]	validation_0-mlogloss:1.25690
# [97]	validation_0-mlogloss:1.25589
# [98]	validation_0-mlogloss:1.25654
# [99]	validation_0-mlogloss:1.25652
# Train Loss: 0.0051 - Train Acc: 1.0000
# Val Loss: 1.2565 - Val Acc: 0.5882
#
# Early stopping at epoch 7
# Final Evaluation:
# Number of classes: 6
# Validation Loss: 1.2565
# Validation Accuracy: 0.5882
